# %% [markdown]
# # Cross Validation
#
# In this notebook, we will explore the concept of cross-validation, which is a powerful technique for evaluating the performance of machine learning models. Cross-validation allows us to split our data into multiple subsets for training and testing, helping to avoid overfitting and ensuring robust evaluation.
#
# ---
#
# ## Exercise 1 : Manual Implementation of Cross-Validation
#
# Use the Diabetes dataset to implement cross-validation manually. Follow these steps:
#
# 1. Split the dataset into `k` folds (e.g., `k=5`).
# 2. For each fold:
#    - Use the fold as the test set.
#    - Use the remaining folds as the training set.
#    - Train a simple linear regression model and compute the mean squared error (MSE) on the test set.
# 3. Calculate the average MSE across all folds.

# %%
# Imports
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
# Load the dataset

# Parameters

# Manual Cross-Validation
mse_scores = []
for i in range(k):
    # Create train-test split

    # Train model

    # Evaluate model

# Calculate average MSE
# Out:
# MSE Scores for each fold: [2785.558425945349, 2994.6347579301796, 3267.9875218086004, 3048.520490621605, 2966.2461464109733]
# Average MSE: 3012.5894685433414

# %% [markdown]
# ## Exercise 2 : Cross-Validation with Scikit-Learn
#
# Repeat the previous exercise using the built-in `KFold` cross-validation from `sklearn.model_selection`. Compare the results with the manual implementation.

# %%
from sklearn.model_selection import KFold

# Initialize KFold

# Scikit-Learn Cross-Validation
mse_scores_sklearn = []
for train_index, test_index in :
    # Create train-test split

    # Train model

    # Evaluate model

# Calculate average MSE
# Out:
# MSE Scores for each fold (Scikit-Learn): [2900.1936284934827, 2662.6376086196146, 3312.3058888352602, 2797.883552555743, 3403.8877929322553]
# Average MSE (Scikit-Learn): 3015.3816942872713

# %% [markdown]
# ## Exercise 3 : Training and Validation Errors Analysis
#
# Analyze the training and validation errors as `k` varies from 2 to 20 groups:
#
# 1. For each `k`, calculate the training error, validation error, and variance of the validation error for each fold.
# 2. Plot:
#    - `k` versus average training error.
#    - `k` versus average validation error.
#    - `k` versus variance of the validation error.
#
# Discuss the observed trade-offs as `k` increases. Also, discuss the effect of `k` on the variance of the validation errors.

# %%
import matplotlib.pyplot as plt

for k in k_values:
    # Cross-Validation

    # Calculate average errors for this k

# Plot results
# Plot training and validation errors

# Plot variance of validation error
